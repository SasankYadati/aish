# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab notebooks! Otherwise use pip install unsloth
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl==0.15.2 triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf datasets huggingface_hub hf_transfer
    # !pip install --no-deps unsloth

# %% [markdown]
# Load model from Lora configs saved in HF repo

# %%
from unsloth import FastLanguageModel

def load_model(model_name, max_seq_length, dtype, load_in_4bit, output_hidden_states=False):
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name=model_name,
        max_seq_length=max_seq_length,
        dtype=dtype,
        load_in_4bit=load_in_4bit,
        output_hidden_states=output_hidden_states,
    )
    return model, tokenizer

model, tokenizer = load_model(
    model_name="saisasanky/Llama-3.1-8B-Instruct-4bit-aish",
    max_seq_length=2048,
    dtype=None,
    load_in_4bit=True,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# Unsloth: Failed to patch Gemma3ForConditionalGeneration.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.3.19: Fast Llama patching. Transformers: 4.51.3.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/55.5k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/168M [00:00<?, ?B/s]
# Unsloth 2025.3.19 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
FastLanguageModel.for_inference(model)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096, padding_idx=128004)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=14336, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %% [markdown]
# Load test dataset from HF

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template = "llama-3.1",
)

from datasets import load_dataset
dataset = load_dataset("westenfelder/NL2SH-ALFA", "test", split = "train")

def formatting_prompts_func(examples):
    nls = examples['nl']
    messages_wo_completion = [
        [
            {"role": "system", "content": "You are an assistant that provides exact bash command for given input"},
            {"role": "user", "content": nl}
        ]
        for nl in nls
    ]
    return {
        'messages_witout_completion': messages_wo_completion,
    }

dataset = dataset.map(formatting_prompts_func, batched=True)
# dataset.drop(columns=['nl','bash'])
dataset[0]
# dataset[0]['messages_with_cmd']
# Out:
# {'nl': 'list files in the current directory',
#  'bash': 'ls',
#  'bash2': 'ls -l',
#  'difficulty': 0,
#  'messages_witout_completion': [{'content': 'You are an assistant that provides exact bash command for given input',
#    'role': 'system'},
#   {'content': 'list files in the current directory', 'role': 'user'}],
#  'messages_with_completion': [{'content': 'You are an assistant that provides exact bash command for given input',
#    'role': 'system'},
#   {'content': 'list files in the current directory', 'role': 'user'},
#   {'content': 'ls', 'role': 'assistant'}]}

# %%
from tqdm import tqdm

# %%
def inference_aish(
    model,
    tokenizer,
    messages
):
    inputs = tokenizer.apply_chat_template(
        messages,
        tokenize=True,
        add_generation_prompt=True,
        return_tensors = "pt",
        padding=True,
        padding_side='left',
    ).to("cuda")
    input_length = inputs.shape[1]
    n_examples = inputs.shape[0]
    batch_size = 32
    completions = []
    for i in tqdm(range(0, len(inputs), batch_size)):
        j = min(i + batch_size, n_examples)
        outputs = model.generate(
            input_ids = inputs[i:j],
            max_new_tokens = 128,
            use_cache = True,
            eos_token_id = tokenizer.eos_token_id,
            pad_token_id = tokenizer.pad_token_id,
            bos_token_id = tokenizer.bos_token_id,
        )

        # Step 3: Extract generated part (exclude the prompt)
        generated_tokens = outputs[:, input_length:]

        completions.extend(
            tokenizer.batch_decode(
                generated_tokens,
                skip_special_tokens=True
            )
        )

    return completions


messages = [example['messages_witout_completion'] for example in dataset]
print(len(messages))
completions = inference_aish(model, tokenizer, messages)
# Out:
# 300
# 100%|██████████| 10/10 [10:09<00:00, 60.99s/it]

# %%
import json

def save_completions_to_jsonl(completions, output_file):
    with open(output_file, 'w') as f:
        for completion in completions:
            json.dump({"completion": completion}, f)
            f.write('\n')

save_completions_to_jsonl(completions, "completions.jsonl")

# %%
n_exact_matches = 0
for completion, example in zip(completions, dataset):
  if completion == example['bash'] or completion == example['bash2']:
    n_exact_matches += 1
  else:
    print("LLM: ", completion)
    print("Human ans: ", example['bash'])
    print("------------------")
# Out:
# LLM:  lsof -i :80
# Human ans:  lsof
# ------------------
# LLM:  mkdir -p /testbed/test_dir
# Human ans:  mkdir /testbed/test_dir
# ------------------
# LLM:  date "+%Y-%m-%d %H:%M:%S"
# Human ans:  date
# ------------------
# LLM:  rm -rf fake_dir
# Human ans:  rmdir fake_dir
# ------------------
# LLM:  printenv | sort
# Human ans:  env
# ------------------
# LLM:  echo ~$USER
# Human ans:  echo $HOME
# ------------------
# LLM:  print $HOME
# Human ans:  echo $PATH
# ------------------
# LLM:  cat /home/user/Downloads/setup_nl2b_fs_1.sh
# Human ans:  cat setup_nl2b_fs_1.sh
# ------------------
# LLM:  nl2b_fs_1.sh|head -5
# Human ans:  head -n 5 setup_nl2b_fs_1.sh
# ------------------
# LLM:  tail -5 setup_nl2b_fs_1.sh
# Human ans:  tail -n 5 setup_nl2b_fs_1.sh
# ------------------
# LLM:  setup_nl2b_fs_1.sh: line 10: print
# Human ans:  sed -n 10p setup_nl2b_fs_1.sh
# ------------------
# LLM:  BASH=/usr/bin/bash
# Human ans:  which bash
# ------------------
# LLM:  vmstat 1
# Human ans:  vmstat
# ------------------
# LLM:  uptime
# Human ans:  w
# ------------------
# LLM:  ps aux
# Human ans:  ps
# ------------------
# LLM:  htop
# Human ans:  pstree
# ------------------
# LLM:  free -m
# Human ans:  free
# ------------------
# LLM:  hostnamectl status
# Human ans:  hostname
# ------------------
# LLM:  ip addr show
# Human ans:  hostname -I
# ------------------
# LLM:  resolvectl status | grep '^DNS' | cut -d '=' -f2-
# Human ans:  cat /etc/resolv.conf | grep nameserver
# ------------------
# LLM:  ip link
# Human ans:  ifconfig
# ------------------
# LLM:  ip route show
# Human ans:  route
# ------------------
# LLM:  last | head -1
# Human ans:  last
# ------------------
# LLM:  lastlog | awk '{print $1,$2,$3}'
# Human ans:  last -w
# ------------------
# LLM:  base64 --decode <<< hello | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base64 --decode | base
# Human ans:  echo 'hello' | base64
# ------------------
# LLM:  base64 --decode 'aGVsbG8='
# Human ans:  echo 'aGVsbG8=' | base64 -d
# ------------------
# LLM:  grep console setup_nl2b_fs_1.sh
# Human ans:  grep 'console' setup_nl2b_fs_1.sh
# ------------------
# LLM:  stat setup_nl2b_fs_1.sh; stat -c %x setup_nl2b_fs_1.sh; stat -c %y setup_nl2b_fs_1.sh
# Human ans:  stat setup_nl2b_fs_1.sh
# ------------------
# LLM:  gzip -c /testbed/hello.php > /testbed/hello.php.gz
# Human ans:  gzip -k /testbed/hello.php
# ------------------
# LLM:  jobs -l
# Human ans:  jobs
# ------------------
# LLM:  ps -o pid,ppid,ni,sz,%mem,%cpu,cmd -p 1234
# Human ans:  nice
# ------------------
# LLM:  echo $BASHPID
# Human ans:  echo $$
# ------------------
# LLM:  groups ${UID}
# Human ans:  groups
# ------------------
# LLM:  id -u $USER
# Human ans:  id
# ------------------
# LLM:  free -m
# Human ans:  lsmem
# ------------------
# LLM:  ssh -v | grep Protocol
# Human ans:  ssh -V
# ------------------
# LLM:  cat ~/.bash_profile
# Human ans:  cat ~/.bashrc
# ------------------
# LLM:  locale -a
# Human ans:  locale
# ------------------
# LLM:  lsblk -d
# Human ans:  lsblk
# ------------------
# LLM:  find. -size +100M
# Human ans:  find . -size +100M -print
# ------------------
# LLM:  wc -l setup_nl2b_fs_1.sh setup_nl2b_fs_1.sh setup_nl2b_fs_1.sh
# Human ans:  wc setup_nl2b_fs_1.sh
# ------------------
# LLM:  sort setup_nl2b_fs_1.sh | sort -f
# Human ans:  sort setup_nl2b_fs_1.sh
# ------------------
# LLM:  grep -v -E '^ *$' setup_nl2b_fs_1.sh | sort -u | grep -v -E '^ *$'
# Human ans:  uniq setup_nl2b_fs_1.sh
# ------------------
# LLM:  netstat -e
# Human ans:  netstat --statistics
# ------------------
# LLM:  ip link
# Human ans:  netstat -i
# ------------------
# LLM:  onacal 3
# Human ans:  cal -3
# ------------------
# LLM:  systemctl --type=notify --state=running
# Human ans:  service --status-all
# ------------------
# LLM:  cat /proc/stat | grep boot_time
# Human ans:  who -b
# ------------------
# LLM:  free -m | awk 'NR==2{print $7}'
# Human ans:  swapon --show
# ------------------
# LLM:  cat /proc/sys/kernel/panic
# Human ans:  sysctl -a
# ------------------
# LLM:  dpkg --list
# Human ans:  dpkg --get-selections
# ------------------
# LLM:  shopt -q -o list_aliases list_types list_functions list_jobs list_expands list_aliases list_types list_functions list_jobs list_expands list_aliases list_types list_functions list_jobs list_expands list_aliases list_types list_functions list_jobs list_expands list_aliases list_types list_functions list_jobs list_expands list_aliases list_types list_functions list_jobs list_expands list_aliases list_types list_functions list_jobs list_expands list_aliases list_types list_functions list_jobs list_expands list_aliases list_types list_functions list_jobs list_expands list_aliases list_types list_functions list_jobs list_expands list_aliases list_types list_functions list_jobs list_expands list
# Human ans:  cat /etc/shells
# ------------------
# LLM:  id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -u <user> || id -
# Human ans:  getent passwd
# ------------------
# LLM:  echo '/usr/local/bin/my_script.sh' | cut -d/ -f5
# Human ans:  basename /usr/local/bin/my_script.sh
# ------------------
# LLM:  wall "System maintenance in 10 minutes!"
# Human ans:  wall 'System maintenance in 10 minutes!'
# ------------------
# LLM:  sh setup_nl2b_fs_1.sh
# Human ans:  file setup_nl2b_fs_1.sh
# ------------------
# LLM:  cat -s setup_nl2b_fs_1.sh
# Human ans:  fold -w 40 setup_nl2b_fs_1.sh
# ------------------
# LLM:  printenv | sort
# Human ans:  getconf -a
# ------------------
# LLM:  gprof --flat-profile -s -y -c -p -L -P -S -D -L -l -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -L -
# Human ans:  ulimit -t
# ------------------
# LLM:  python -c "import sys; print(sys.maxsize)"
# Human ans:  getconf LONG_BIT
# ------------------
# LLM:  wc -w setup_nl2b_fs_1.sh | grep -o the | wc -l
# Human ans:  grep -o 'the' setup_nl2b_fs_1.sh | wc -l
# ------------------
# LLM:  ls | wc -l
# Human ans:  ls -a | wc -l
# ------------------
# LLM:  setup_nl2b_fs_1.sh | head -1
# Human ans:  sed -n '1p' setup_nl2b_fs_1.sh
# ------------------
# LLM:  tail setup_nl2b_fs_1.sh | head -n 1
# Human ans:  sed -n '$p' setup_nl2b_fs_1.sh
# ------------------
# LLM:  setup_nl2b_fs_1.sh | sed -n '3,5p'
# Human ans:  sed -n '3,5p' setup_nl2b_fs_1.sh
# ------------------
# LLM:  sed -n 1~2p setup_nl2b_fs_1.sh
# Human ans:  sed -n '1~2p' setup_nl2b_fs_1.sh
# ------------------
# LLM:  find -maxdepth 1 -empty -type f
# Human ans:  find . -maxdepth 1 -type f -empty
# ------------------
# LLM:  setup_nl2b_fs_1.sh | grep -E.\{1,20\}
# Human ans:  awk 'length < 40' setup_nl2b_fs_1.sh
# ------------------
# LLM:  egrep 'the' setup_nl2b_fs_1.sh
# Human ans:  grep 'the' setup_nl2b_fs_1.sh
# ------------------
# LLM:  grep -E 'the.*a' setup_nl2b_fs_1.sh
# Human ans:  grep 'the' setup_nl2b_fs_1.sh | grep 'a'
# ------------------
# LLM:  sha512 setup_nl2b_fs_1.sh
# Human ans:  sha512sum setup_nl2b_fs_1.sh
# ------------------
# LLM:  gpg --symmetric --cipher-algo AES256 --batch --yes --passphrase 'password' setup_nl2b_fs_1.sh > out.enc
# Human ans:  openssl enc -aes-256-cbc -in setup_nl2b_fs_1.sh -pass pass:password -out out.enc
# ------------------
# LLM:  echo "hello" > world.txt
# Human ans:  echo 'hello' > world.txt
# ------------------
# LLM:  dig +short myip.opendns.com
# Human ans:  curl ipinfo.io/ip
# ------------------
# LLM:  find /testbed -name "*.java" -exec md5sum {} \; | sort | uniq -d
# Human ans:  md5sum /testbed/*.java | awk '{print $1}' | sort | uniq -d
# ------------------
# LLM:  find /testbed/dir2/subdir2 -type f | sort | cut -d''-f1 | xargs md5sum | sort | cut -d''-f1 | xargs md5sum
# Human ans:  find /testbed/dir2/subdir2 -type f -print0 | sort -z | xargs -0 md5sum | awk '{print $1}' | md5sum
# ------------------
# LLM:  sort -r "$FILES" | md5sum
# Human ans:  cat $(echo $FILES | tr ' ' '\n' | sort) | md5sum
# ------------------
# LLM:  find /testbed/dir1/subdir1 -name "*.py" | sort | md5sum | md5sum
# Human ans:  find /testbed/dir1/subdir1 -type f -name *.py -exec md5sum {} + | awk '{print $1}' | sort | md5sum
# ------------------
# LLM:  du -h --max-depth=1 /testbed/*.txt | sort -h | sed's/^/$(hostname)/ '
# Human ans:  find /testbed -name "*.txt" -exec du {} + | awk -v hostname="$(hostname)" '{print hostname, $0}'
# ------------------
# LLM:  find /testbed -iname "*.php" -exec chmod 755 {} \;
# Human ans:  find /testbed -name "*.php" -exec chmod 755 {} \; -exec /bin/echo {} \; | wc -l
# ------------------
# LLM:  screen -r 2>/dev/null || echo False
# Human ans:  pstree -s $$ | grep -q "screen" && echo "True" || echo "False"
# ------------------
# LLM:  cmp --silent /testbed/dir3/subdir1/subsubdir1/textfile3.txt /testbed/dir2/subdir1/textfile2.txt
# Human ans:  comm -23 <(sort /testbed/dir3/subdir1/subsubdir1/textfile3.txt | uniq) <(sort /testbed/dir2/subdir1/textfile2.txt | uniq) | head -1 | grep -q '.' && echo "False" || echo "True"
# ------------------
# LLM:  find /testbed -type f -name "*.txt" -exec wc -w {} \; | awk '{sum+=$1} END {print sum/NR}' | awk '{print $1/2}'
# Human ans:  find /testbed -name '*.txt' -print0 | xargs -0 wc -w | awk 'END { print $1/(NR-1) }'
# ------------------
# LLM:  find /testbed -name '*.txt' -size -6c | awk '{sum+=$1} END {print sum/NR}'
# Human ans:  find /testbed -name '*.txt' -print0 | xargs -0 wc -w | awk '$1 < 6 {v += $1; c++} END {print v/c}'
# ------------------
# LLM:  cp /testbed/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??/??
# Human ans:  find /testbed -path '*FooBar*' -print0 | xargs -0 -I{} cp -r {} /testbed/dir3/subdir1/subsubdir1/tmp
# ------------------
# LLM:  find /testbed -iname *.txt -print | xargs grep -i another
# Human ans:  find /testbed -name "*.txt" \( -exec echo {} \; -o -exec true \; \) -exec grep another {} \;
# ------------------
# LLM:  hexdump -n 16 -e '1/1 "%02x "' /testbed/textfile7.txt
# Human ans:  head /testbed/textfile7.txt -c16 | od -tx1 -w16 | head -n1 | cut -d' ' -f2- | tr -d ' '
# ------------------
# LLM:  rsync -av --files-from=/testbed/file.txt --include=FooBar/ /testbed/.
# Human ans:  find /testbed -type f -path '*FooBar*' | xargs -i cp -p "{}" .
# ------------------
# LLM:  cp /testbed/dir3/subdir1/subsubdir1/tmp/*FooBar* /testbed/dir3/subdir1/subsubdir1/tmp/
# Human ans:  find /testbed -name '*FooBar*' -print0 | xargs -0 -I{} cp -R {} /testbed/dir3/subdir1/subsubdir1/tmp
# ------------------
# LLM:  find /testbed -name '*.c' | xargs wc -l
# Human ans:  find /testbed -name "*.c" -print0 | xargs -0 cat | wc -l
# ------------------
# LLM:  find. -name "*.php" -exec wc -l {} +
# Human ans:  find . -type f -name '*php' | xargs cat | wc -l
# ------------------
# LLM:  find /testbed -type f -name "*.php" | xargs wc -l
# Human ans:  find /testbed/ -name '*.php' | xargs cat | wc -l
# ------------------
# LLM:  find /testbed -iname '*.py' | md5sum
# Human ans:  find /testbed -type f -name "*.py" -exec md5sum {} +
# ------------------
# LLM:  find /testbed -iname *.html | grep -c foo
# Human ans:  find /testbed -name "*.html" | xargs grep -l foo | wc -l
# ------------------
# LLM:  find /testbed -iname *.php | wc -l && find /testbed -iname *.php | xargs chmod 755
# Human ans:  find /testbed -name "*.php" -exec chmod 755 {} \; -exec /bin/echo {} \; | wc -l
# ------------------
# LLM:  find /testbed -name '*file*' | wc -l
# Human ans:  find /testbed/ -name '*file*' | sort | xargs wc -l
# ------------------
# LLM:  find ${DIRECTORY} -type f -name '*[aeiou]*' | wc -l
# Human ans:  find ${DIRECTORY} -type f -print | sed -e 's@^.*/@@' | grep '[aeiouyAEIOUY]' | wc -l
# ------------------
# LLM:  find /testbed -type f | cut -d '.' -f 2- | sort -u | xargs -I {} find /testbed -type f | grep -c {}
# Human ans:  find /testbed -type f | sed -e 's/.*\.//' | sed -e 's/.*\///' | sort | uniq -c | sort -rn
# ------------------
# LLM:  find /testbed -name "*.gz" | xargs gzip -cd | wc -l
# Human ans:  find /testbed -type f -name '*.gz' | xargs zcat | wc -l
# ------------------
# LLM:  wc -l --files0-from=/testbed/*.php | sort
# Human ans:  find /testbed -name '*.php' -type f | sort | xargs wc -l
# ------------------
# LLM:  find /testbed -name "*.php" | xargs wc -l | sort -rn -k2
# Human ans:  find /testbed -name '*.php' -type f | xargs wc -l | sort -nr
# ------------------
# LLM:  awk '{a[$1]++}END{for(i in a)print i,a[i]}' /etc/networks | sort -rn -k2
# Human ans:  grep -oE '([0-9]{1,3}\.){3}[0-9]{1,3}' /etc/networks | sort | uniq -c | sort -nr
# ------------------
# LLM:  find /testbed -name "*.php" | xargs grep -E -o '\w+' | wc -l
# Human ans:  find /testbed -name '*.php' | xargs cat | awk '/[a-zA-Z0-9]/ {i++} END{print i}'
# ------------------
# LLM:  find /testbed -type f \( -name "*.php" -o -name "*.js" \) | wc -l
# Human ans:  find /testbed -name '*.js' -or -name '*.php' | xargs wc -l | grep 'total'  | awk '{print $1}'
# ------------------
# LLM:  find testbed -name dir1 -type d | xargs -I {} mkdir -p {}/abc.txt
# Human ans:  find /testbed -type d -name "dir1" -print |  sed 's/$/\/abc.txt/g' | xargs touch
# ------------------
# LLM:  find /var/log -mtime +1 -print0 | tar -czvf logs.tar.gz -
# Human ans:  find /var/log/ -mtime +1 | xargs  tar -czvPf  /testbed/logs.tar.gz
# ------------------
# LLM:  find "/testbed/dir3/subdir1/subsubdir1/tmp" -type f -mtime +2 -delete
# Human ans:  find /testbed/dir3/subdir1/subsubdir1/tmp -type f -mtime +2 -print0 | xargs -0 rm -f
# ------------------
# LLM:  find /testbed -type f -print0 | xargs -0 -r du -b | sort -rn | head -n 5
# Human ans:  find /testbed -type f -exec du -b {} + | sort -rh | head -n 5
# ------------------
# LLM:  find /testbed -size -1k -type f | sort -n | head -5
# Human ans:  find /testbed -type f -size +0c -exec du -b {} + | sort -n | head -n 5
# ------------------
# LLM:  find /testbed -type f -printf '%s %p\n' | sort -n | head -5 | cut -d''-f2-
# Human ans:  find /testbed -type f -exec ls -s {} \; | sort -n  | head -5
# ------------------
# LLM:  du -a /testbed | sort -rn -k 1 | head -5
# Human ans:  find /testbed -type f -maxdepth 1 -exec du -b {} + | sort -rh | head -n 5
# ------------------
# LLM:  find testbed -name *.java | grep Hello
# Human ans:  find /testbed -name "*.java" -exec grep -Hin Hello {} + | cut -d ":" -f 1 | xargs -I{} basename {}
# ------------------
# LLM:  find /testbed -iname '*.*' -type f | sort | uniq -d -c | sort -rn | grep -v'1 '
# Human ans:  find /testbed -type f | awk -F/ '{print $NF}' | sort -f | uniq -i -d
# ------------------
# LLM:  find testbed/dir1 -print0 | xargs -0 -i -r find testbed/dir2 -print0 | sort -z | uniq -z
# Human ans:  comm -23 <(find /testbed/dir1 | sed 's#/testbed/dir1/##' | sort) <(find /testbed/dir2 | sed 's#/testbed/dir2/##' | sort) | sed 's#^#/testbed/dir1/#'
# ------------------
# LLM:  find /testbed -type f -exec grep -q "Hello" {} \; -print
# Human ans:  grep -rl 'Hello' /testbed | xargs -I {} dirname {} | sort | uniq
# ------------------
# LLM:  find /testbed -name "*.java" | wc -l
# Human ans:  find /testbed -name '*.java' -print0 |xargs -0 wc -l|grep 'total' |awk '{ print $1 }'
# ------------------
# LLM:  find /testbed/dir1 -type f -perm 3315
# Human ans:  find /testbed/dir1 -perm 1553
# ------------------
# LLM:  find /testbed -name "*.php" | xargs grep -i "world"
# Human ans:  find /testbed -name '*.php' -exec grep -iq "world" {} \; -print
# ------------------
# LLM:  find /system/folder1 -type f -exec grep -Hn 'hello' {} \;
# Human ans:  grep -inr "Hello" /system/folder1
# ------------------
# LLM:  find /system -type f -exec sed -i "s/foo/1foo/g" {} \;
# Human ans:  grep -rnw /system -e "foo"
# ------------------
# LLM:  tree -L 2 -d /system
# Human ans:  tree /system
# ------------------
# LLM:  find /system/folder2 -type f -o -type d -print
# Human ans:  tree -a /system/folder2
# ------------------
# LLM:  find /system -type f -name "*.out"
# Human ans:  find /system -type f -name "*.out" -print0 | xargs -0 -n1 dirname | sort -u
# ------------------
# LLM:  find /system -name "*.txt" -delete
# Human ans:  yes y | rm -r /system/*.txt
# ------------------
# LLM:  find /system/folder3/temp -type d -empty -delete -print
# Human ans:  find /system/folder3/temp -type d -empty -exec rmdir -vp --ignore-fail-on-non-empty {} +
# ------------------
# LLM:  find /system/folder1 -maxdepth 1 -type f -not -name '*txt' -delete
# Human ans:  find /system/folder1 -type f -not -name '*txt' | xargs rm
# ------------------
# LLM:  mv /system/folder2/* /system/folder2/
# Human ans:  find /system/folder2 -type f -name '*special*' ! -path '*/special/*' -execdir bash -c 'mv "$0" "${0/special/regular}"' {} \;
# ------------------
# LLM:  agrep -q --file-list /system --recursive --foo foo
# Human ans:  grep -r "foo" /system | tee >(wc -l)
# ------------------
# LLM:  find /system/folder3/ -type f | cut -d'/' -f4-
# Human ans:  find /system/folder3/ -type f -exec basename {} \;
# ------------------
# LLM:  tar -xvf /system/folder2.tar.gz | grep special
# Human ans:  zcat -r /system/folder2.tar.gz | grep "special"
# ------------------
# LLM:  awk '{print substr($0,1,length($0)-1)}' "system/folder3/temp/temp1/text1.txt"
# Human ans:  cat /system/folder3/temp/temp1/text1.txt | sed 's/\r$//' | od -c
# ------------------
# LLM:  find /system/folder1 -name "*.doc" -delete
# Human ans:  find /system/folder1 -name '*.doc' -exec rm "{}" \;
# ------------------
# LLM:  find /system/folder1 -name "*.log" -exec rm {} \;
# Human ans:  find /system/folder1 -name '*.log' -print0 | xargs -0 rm
# ------------------
# LLM:  find /system -maxdepth 1 -name "*.txt" -delete
# Human ans:  find /system -name '*.txt' -maxdepth 1 | xargs rm
# ------------------
# LLM:  find '/system/folder3/backup_dbg' -name '*.sql' -mtime +25 -delete
# Human ans:  find /system/folder3/backup_dbg/*.sql -mtime +25 -exec rm -f {} \;
# ------------------
# LLM:  find /system/folder1 -name "*.txt" -mtime +5 -delete
# Human ans:  find /system/folder1 -mmin +5 -type f -name "*.txt" -delete
# ------------------
# LLM:  find /system/folder1 -maxdepth 1 -mtime +5 -type f -not -name "keep.txt" -exec rm {} \;
# Human ans:  find /system/folder1 -maxdepth 1 -mmin +5 -type f -name "*.txt" ! -name "keep.txt" -delete
# ------------------
# LLM:  find '/system/folder1' -name 'new*.sh' -delete
# Human ans:  find /system/folder1 -name 'new*.sh' -exec rm -f '{}' \;
# ------------------
# LLM:  find /system -name 'a.out' -o -name '*.o' -o -name 'core' | xargs rm -f
# Human ans:  find /system \( -name a.out -o -name '*.o' -o -name 'core' \) -exec rm {} \;
# ------------------
# LLM:  tail -n 5 /system/folder1/data.csv
# Human ans:  cat /system/folder1/data.csv | rev | cut -d, -f-5 | rev
# ------------------
# LLM:  rm -rf /system/temp
# Human ans:  find /system -name "temp" -type d -delete
# ------------------
# LLM:  find /system/folder3/temp -type f -empty -delete
# Human ans:  find /system/folder3/temp -type f -empty -print | xargs rm -f
# ------------------
# LLM:  find /system -name 'a.out' -o -name '*.o' -mtime -7 -exec rm -f {} \;
# Human ans:  find /system \( -name a.out -o -name '*.o' \) -mtime -7 -exec rm {} \;
# ------------------
# LLM:  find /system/folder3/temp -type f -name '.DS_Store' -o -type f -name '._.DS_Store' -o -type f -name '._*' -o -type f -name '.TemporaryItems' -o -type f -name '.apdisk' -delete
# Human ans:  find /system/folder3/temp \( -name '.DS_Store' -or -name '._.DS_Store' -or -name '._*' -or -name '.TemporaryItems' -or -name '.apdisk' \) -exec rm -rf {} \;
# ------------------
# LLM:  paste -d " " -s "1/2 [3] (27/03/2012 19:32:54) word word word word 4/5" | sed's/[a-zA-Z]//g' | sed's/[()//g' | column -t
# Human ans:  echo '1/2 [3] (27/03/2012 19:32:54) word word word word 4/5' | sed -e 's/(.*)//' -e 's/[^0-9]/ /g' | column -t
# ------------------
# LLM:  rm /system/folder1/text2 /system/folder1/text3 /system/folder1/text4
# Human ans:  find /system/folder1 -name 'text[2-4]*' -exec rm {} \;
# ------------------
# LLM:  find /system -size -1k -delete
# Human ans:  find /system -type f -size -1k -exec rm {} +
# ------------------
# LLM:  find /system -mtime +31 -exec rm -f {} \;
# Human ans:  find /system -type f -mtime +31 -exec rm -f {} \;
# ------------------
# LLM:  echo -e "/system/folder3/temp/temp1/text1.txt"
# Human ans:  paste -sd "" /system/folder3/temp/temp1/text1.txt
# ------------------
# LLM:  git diff --name-only /system/folder1 /system/folder2
# Human ans:  diff -qr /system/folder1 /system/folder2 | sort
# ------------------
# LLM:  df -k /system | awk '{print $4}' | xargs -i du -s --si | awk '{print $1}' | awk '{print $1}' | xargs -i df -k /system | awk '{print $4}' | awk '{print $1}' | awk '{print $1}' | xargs -i du -s --si | awk '{print $1}' | awk '{print $1}' | xargs -i df -k /system | awk '{print $4}' | awk '{print $1}' | awk '{print $1}' | awk '{print $1
# Human ans:  df -m /system
# ------------------
# LLM:  find /system -maxdepth 1 -mindepth 1 | wc -l
# Human ans:  find /system -type d | wc -l
# ------------------
# LLM:  tar -czf /mytarfile.tgz --mtime 2023-01-01 --owner=0 --group=0 --mtime 2023-01-01 --files-from=/dev/null /system/folder1
# Human ans:  tar --mtime='2023-01-01' --owner=0 --group=0 -czf mytarfile.tgz `find /system/folder1 -mtime -60`
# ------------------
# LLM:  date "+%Y-%m-%d %H:%M:%S 1" >> /system/folder3/temp/empty.txt
# Human ans:  echo $(date) "1" | tee -a /system/folder3/temp/empty.txt
# ------------------
# LLM:  find /system -type f -name "*.txt" -exec cat {} \; > /system/folder3/temp/concat.txt
# Human ans:  find /system -name "*.txt" -not -name "concat.txt" -print -exec cat {} \; > /system/folder3/temp/concat.txt
# ------------------
# LLM:  tar -czf /backup/system.tar.gz /system
# Human ans:  find /system -depth -print | cpio -dump /backup
# ------------------
# LLM:  find /system -type f -not -name '*text*' -exec cp {} '/system/folder3/backup_dbg/backup' \;
# Human ans:  find /system -maxdepth 1 -type f ! -name '*text*' -exec cp {} /system/folder3/backup_dbg/backup \;
# ------------------
# LLM:  dump -b -a /system/text1.txt
# Human ans:  od -t c /system/text1.txt
# ------------------
# LLM:  tar -czf compress_folder1.tar.gz -C /system/ --mtime=2023-01-01 --owner=0 --group=0 folder1
# Human ans:  tar --mtime='2023-01-01' --owner=0 --group=0 -zcf compress_folder1.tar.gz /system/folder1
# ------------------
# LLM:  curl -o /system/textfile.txt http://example.com/textfile.txt
# Human ans:  curl http://example.com/textfile.txt -o /system/textfile.txt
# ------------------
# LLM:  find /system -size +10
# Human ans:  find /system -size +10c -print
# ------------------
# LLM:  find /system -name "*.txt" | xargs md5sum | sort
# Human ans:  find /system -type f -name '*.txt' -exec md5sum {} + | awk '{print $1}' | sort
# ------------------
# LLM:  awk '{if ($0 ~ /127\.0\.1\.1/) {print $1}}' /etc/hosts
# Human ans:  more /etc/hosts | grep `hostname` | awk '{print $1}'
# ------------------
# LLM:  find /workspace -mtime -30
# Human ans:  find /workspace -daystart -type f -mtime -30
# ------------------
# LLM:  find /workspace -name "*.c" -size +1k
# Human ans:  find /workspace -name '*.c' -size +1k -print
# ------------------
# LLM:  find /workspace -mmin +60
# Human ans:  find /workspace -type f -cmin +60
# ------------------
# LLM:  find /workspace -amin -60
# Human ans:  find /workspace -type f -amin +60
# ------------------
# LLM:  ls /workspace
# Human ans:  find /workspace -maxdepth 1 -type d
# ------------------
# LLM:  find /workspace -size 0 -print
# Human ans:  find /workspace -empty
# ------------------
# LLM:  find /workspace -size 0
# Human ans:  find /workspace -empty -exec ls {} \;
# ------------------
# LLM:  find /workspace -size +1k -exec rm -f {} \;
# Human ans:  find /workspace -type f -size +1k -delete
# ------------------
# LLM:  find /workspace -type f -perm g=r
# Human ans:  find /workspace -perm 400 -type f -exec ls -l {} \;
# ------------------
# LLM:  find /workspace -type f -perm 777
# Human ans:  find /workspace -perm 777 -type f -exec ls -l {} \;
# ------------------
# LLM:  find /workspace -type f -exec file {} \;
# Human ans:  find /workspace -name "*.txt" -exec ls -ld {} \;
# ------------------
# LLM:  find /workspace -type f -not -path '/workspace/*' -exec mv {} / \;
# Human ans:  find /workspace -maxdepth 1 -type f -exec mv -t / {} +
# ------------------
# LLM:  find /workspace -mtime 1 -exec mv {}. \;
# Human ans:  find /workspace -atime -1 -type f -exec mv {} / \;
# ------------------
# LLM:  find /workspace/dir1 -iname '*hello*'
# Human ans:  find /workspace/dir1 -type f -exec grep -il 'hello' {} \;
# ------------------
# LLM:  du /workspace
# Human ans:  du -sh /workspace
# ------------------
# LLM:  tail -n 1 /workspace/dir1/long.txt | cut -d''-f4
# Human ans:  tac /workspace/dir1/long.txt | awk 'NF{print $NF; exit}'
# ------------------
# LLM:  du -s /workspace/* | sort -rn | head -3
# Human ans:  du -a /workspace | sort -nr | head -n 3
# ------------------
# LLM:  head -1 /workspace/dir1/long.txt
# Human ans:  head -n1 /workspace/dir1/long.txt
# ------------------
# LLM:  tail -n 1 /workspace/dir1/a.txt
# Human ans:  tac /workspace/dir1/a.txt | grep -m 1 '.'
# ------------------
# LLM:  git rm -rf --cached /workspace
# Human ans:  find /workspace -type f -delete
# ------------------
# LLM:  find /workspace -size +1k -size -32k
# Human ans:  find /workspace -type f -size +1k -size -32k
# ------------------
# LLM:  find /workspace/ -type f | sed's/[^\/]*\///' | sort -u | sort -d
# Human ans:  find /workspace -type f | awk -F/ '{print NF, $0}' | sort -n
# ------------------
# LLM:  find /workspace -type f -size +1k -exec ls -l {} \; | sort -r -k 5
# Human ans:  find /workspace -type f -size +1k -exec ls -ls {} + | sort -n | tail -1
# ------------------
# LLM:  find /workspace -type f -name "*.txt" -not -perm /u+w -exec ls -ld {} \;
# Human ans:  find  /workspace -type f \( -iname "*.txt" -not -perm -o=w \)
# ------------------
# LLM:  find /home/user/workspace -name mysql
# Human ans:  find  /workspace -name mysql -type d
# ------------------
# LLM:  find /workspace -iname '*.*' -print0 | sort -z | uniq -z -d
# Human ans:  find /workspace -type f | awk -F/ '{print $NF}' | sort -f | uniq -i -d
# ------------------
# LLM:  find /workspace/ -name old2.txt -exec stat -c "%a %y" {} \;
# Human ans:  find /workspace -name old2.txt | xargs ls -tl
# ------------------
# LLM:  find /workspace -type f -name "*.txt" -exec grep -q "hello" {} \; -print
# Human ans:  find  /workspace -type f | xargs grep -l "hello"
# ------------------
# LLM:  find /workspace | while read f; do echo "$f"; md5sum "$f"; done
# Human ans:  find /workspace -type f -exec md5sum {} + | awk '{print $2 " " $1}'
# ------------------
# LLM:  find /workspace -type f -exec md5sum {} \;
# Human ans:  find /workspace -type f -exec md5sum {} + | sort
# ------------------
# LLM:  find /workspace -type f | cut -d '.' -f 2- | cut -d '.' -f 1-6 | sort -u | wc -l
# Human ans:  find /workspace -type f -name '*.*' | awk -F. 'NF>1 {ext=tolower($NF); if (length(ext) >= 3 && length(ext) <= 6) print ext}' | sort | uniq -c | wc -l
# ------------------
# LLM:  rsync -avz /workspace/ /usr/
# Human ans:  find /workspace -type d -print|sed 's@^@/usr/@'|xargs mkdir -p
# ------------------
# LLM:  find /workspace -type f -print0 | xargs -0 ls -ld
# Human ans:  find /workspace -type f -printf '%T+ %p\n' | sort | head -n 1 | awk '{print $2}' | xargs ls -l
# ------------------
# LLM:  find /workspace -maxdepth 1 -type d -exec du -s {} \; | sort -rn | head -n2 | awk '{print $2}'
# Human ans:  find /workspace -type d -print0 | xargs -0 du | sort -n | tail -2 | cut -f2 | xargs -I{} du -sh {}
# ------------------
# LLM:  find /workspace -type f -exec sha256sum {} \; | sort | uniq -d | cut -d\  -f2- | xargs -d$'\n' find /workspace -type f -exec sha256sum {} \; | sort | uniq -d | cut -d\  -f2- | xargs -d$'\n'
# Human ans:  find /workspace -type f | xargs md5sum | sort | uniq -Dw32
# ------------------
# LLM:  mkdir -p $(sort -u -f -t / -d -k 1,1 /workspace/files.txt | cut -d/ -f2- | tr '\n''')
# Human ans:  cat /workspace/files.txt |xargs -I {} dirname "{}"| sort -u | xargs -I{} mkdir -p "{}"
# ------------------
# LLM:  du -b /workspace/files.txt | awk '{sum+=$1} END {print sum}'
# Human ans:  cat /workspace/files.txt | xargs du -b | tail -1 | awk '{print $1}'
# ------------------
# LLM:  find /workspace -name.* -exec ls -d {} \;
# Human ans:  find /workspace -maxdepth 1 -type f -name '.*' -exec sh -c 'mv "$0" "${0%/\.*}/${0##*/.}"' {} \;
# ------------------
# LLM:  git diff --numstat /workspace/dir1/long.txt /workspace/dir1/terminate.txt
# Human ans:  diff /workspace/dir1/long.txt /workspace/dir1/terminate.txt | grep ^[\>\<] | wc -l
# ------------------
# LLM:  git diff --no-unified --name-only --diff-context --exit-code /workspace/dir1/terminate.txt /workspace/dir1/long.txt | wc -l
# Human ans:  diff -U 0 /workspace/dir1/terminate.txt /workspace/dir1/long.txt | grep -v ^@ | wc -l
# ------------------
# LLM:  wc -l /workspace/dir1/a.txt
# Human ans:  awk '!/^[[:space:]]*$/{++x} END{print x}' /workspace/dir1/a.txt
# ------------------
# LLM:  ln -s -f /workspace/results.txt ~/newlinks
# Human ans:  cat /workspace/results.txt | xargs -I{} ln -s {} ~/newlinks
# ------------------
# LLM:  find /workspace -type f -name ".*" -delete
# Human ans:  find /workspace -type f -name '.*' -delete
# ------------------
# LLM:  dprintf -f -e -w 8 /workspace/dir1/long.txt
# Human ans:  od -t fD /workspace/dir1/long.txt
# ------------------
# LLM:  git diff --no-commit --cached --name-only --diff-filter=ACMRTUXB /workspace/dir1 /workspace/dir2
# Human ans:  diff <(ls /workspace/dir1) <(ls /workspace/dir2)
# ------------------
# LLM:  stat /workspace/dir1/sum.c | awk '{print $2}'
# Human ans:  du -sb /workspace/dir1/sum.c | cut -f1
# ------------------
# LLM:  awk -F/ '{print $(NF)}' /workspace/dir1/file.txt
# Human ans:  rev /workspace/dir1/file.txt | cut -d/ -f1 | rev
# ------------------
# LLM:  du -h --max-depth=1 /workspace | sort -rh
# Human ans:  du /workspace -a -h | sort -hr
# ------------------
# LLM:  df /workspace | awk '{print ($4 / $2) * 100}'
# Human ans:  df -k /workspace | tail -1 | awk '{print $5}'
# ------------------
# LLM:  touch workspace/Icon\r
# Human ans:  echo $'workspace/Icon\r' | xargs touch
# ------------------
# LLM:  ln -s /workspace/dir1/root /workspace/dir1/
# Human ans:  ln /workspace/dir1 -s /
# ------------------
# LLM:  find /workspace -type f -exec stat -c "%n %u %g %a" {} \;
# Human ans:  tree /workspace -p -u -g -f
# ------------------
# LLM:  grep -r -i hello /workspace
# Human ans:  find /workspace -type f -print0  | xargs -0 grep -iH "hello"
# ------------------
# LLM:  find /workspace -name *.gz | xargs gzip -d
# Human ans:  find /workspace -name '*.gz' -print0 | xargs -0 gunzip
# ------------------
# LLM:  tar -xzf /workspace/archive.tar.gz -C /backup
# Human ans:  gzip -dc /workspace/archive.tar.gz | tar -xf - -C /backup
# ------------------
# LLM:  uname -r | cut -d'.' -f1,2 | awk '{print $1"."$2"#"}' | cut -d''-f2 | cut -d'#' -f1
# Human ans:  uname -v | grep -o '#[0-9]\+'
# ------------------
# LLM:  host 127.0.0.1 | nsswitch -type hosts
# Human ans:  dig -x 127.0.0.1
# ------------------
# LLM:  ls -l /bin/grep
# Human ans:  ls -ald `which grep`
# ------------------
# LLM:  extract-host-name-part-from-http-www.google.com.bashextract-host-name-part-from-http-www.google.com="echo www.google.com | sed's/.*\///'"
# Human ans:  echo "http://www.google.com" | cut -d'/' -f3
# ------------------
# LLM:  declare -p;
# Human ans:  env | sed 's/;/\\;/g'
# ------------------
# LLM:  ps -ef --forest
# Human ans:  pstree -a
# ------------------
# LLM:  seq 1 10 | tr'' ":"
# Human ans:  yes | head -n10 | grep -n . | cut -d: -f1 | paste -sd:
# ------------------
# LLM:  rlprint-bindingsassistant
#
# rlprint-bindings
# Human ans:  bind -P
# ------------------
# LLM:  bind -f /dev/null | grep p | cut -d''-f2 | sed's/)/)/' | sed's/(//g' | sed's/ //g' | sed's/.*\(.*\)/\1/' | sed's/.*\(.*\)/\1/' | sed's/.*\(.*\)/\1/' | sed's/.*\(.*\)/\1/' | sed's/.*\(.*\)/\1/' | sed's/.*\(.*\)/\1/' | sed's/.*\(.*
# Human ans:  bind -l | grep p
# ------------------
# LLM:  dig +short google.com @8.8.8.8 > address && cat address
# Human ans:  address=$(dig +short google.com | grep -E '^[0-9.]+$' | head -n 1) && echo $address
# ------------------
# LLM:  sed's/[^0-9;]//g' <<< "  Hello world;876	  "
# Human ans:  echo '  Hello world;876	  ' | tr -cd ';0-9'
# ------------------
# LLM:  echo -s "  Hello world!	  " | xargs
# Human ans:  echo '  Hello world!	  ' | sed -e 's/^[ \t]*//' | sed -e 's/[ \t]*$//'
# ------------------
# LLM:  cut -c1-26 "987654321"
# Human ans:  echo 987654321 | rev | cut -c 4- | rev
# ------------------
# LLM:  findmnt -n -o source -v /
# Human ans:  df . | tail -1 | awk '{print $1}'
# ------------------
# LLM:  declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -A H=0; declare -
# Human ans:  env | awk -F= '{if($1 ~ /H/) print $1}'
# ------------------
# LLM:  users | sort | uniq
# Human ans:  who | cut -d' ' -f1 | sort | uniq
# ------------------
# LLM:  ping 192.168.1.1
# Human ans:  ping -w 1 192.168.1.1
# ------------------
# LLM:  printf=99=
# Human ans:  seq -s= 100|tr -d '[:digit:]'
# ------------------
# LLM:  who|wc -l
# Human ans:  who | awk -F' ' '{print $1}' | sort -u | wc -l
# ------------------
# LLM:  cal 12 2120..1
# Human ans:  cal -3 12 2120
# ------------------
# LLM:  sort -k 1,1 -u /etc/group | cut -d: -f1
# Human ans:  cut -d: -f1 /etc/group | sort
# ------------------
# LLM:  sum=0;for i in {1..10};do sum=$((sum+i));done;echo $sum
# Human ans:  seq 10 | jq -s 'add'
# ------------------
# LLM:  find /home/parallels/testbed/ -maxdepth 1 -exec ls -l {} \; | wc -l
# Human ans:  find /testbed | wc -l
# ------------------
# LLM:  find testbed -iname "*.py" | wc -l
# Human ans:  find testbed -type f -name "*.py" | wc -l
# ------------------
# LLM:  sort -r -f -o textfile1.txt.r textfile1.txt
# Human ans:  sort -r /testbed/dir1/textfile1.txt > /testbed/dir1/textfile1_reverse_sorted.txt
# ------------------
# LLM:  find testbed -iname "*shell*"
# Human ans:  find /testbed -type f -exec grep -l 'Shell' {} +
# ------------------
# LLM:  find testbed -type l
# Human ans:  find /testbed -type l
# ------------------
# LLM:  du -h testbed/|tail -1|cut -d'' -f1>total_size.txt
# Human ans:  du -sh testbed/ | awk '{print $1}' > total_size.txt
# ------------------
# LLM:  du -h /testbed/dir1/* | sort -rn -k1
# Human ans:  ls -lhS /testbed/dir1
# ------------------
# LLM:  find /testbed/dir2 -type f | xargs wc -l
# Human ans:  grep -rl . /testbed/dir2 | xargs wc -l
# ------------------
# LLM:  find /testbed/dir3 -type f -exec ls -s {} \; | sort -rn -k2 | head -n 3 | cut -d''-f2- | xargs -I {} ls -l {} | cut -d''-f5- | cut -d''-f1,2 | sort -k2 -rn | head -n 3
# Human ans:  find /testbed/dir3 -type f -exec ls -lhS {} + | sort -rh -k5 | head -n 3
# ------------------
# LLM:  find /testbed -mtime -2 -print0 | tar -czf archive.tar.gz -
# Human ans:  find /testbed -type f -mmin -120 -print0 | xargs -0 tar -czf /testbed/archive.tar.gz
# ------------------
# LLM:  find /testbed -maxdepth 1 -type d! -name subdir1
# Human ans:  ls -d /testbed/*/ | grep -v /subdir1/
# ------------------
# LLM:  find /testbed -type f -exec grep -q 'text file' {} \; -print
# Human ans:  grep -r 'text file' /testbed
# ------------------
# LLM:  find /testbed -type f | sort | xargs md5sum | awk '{print $2}' | sort | uniq > hashes.txt
# Human ans:  find /testbed -type f -exec md5sum {} + > /testbed/hashes.txt
# ------------------
# LLM:  find /testbed -mtime -1
# Human ans:  find /testbed -type f -mtime -1 -print
# ------------------
# LLM:  find /testbed -type f -exec sed -i's/Hello/Hi/g' {} \;
# Human ans:  grep -rl "Hello" /testbed | xargs sed -i 's/Hello/Hi/g'
# ------------------
# LLM:  git diff --no-color --side-by-side --line-numbers --separator=| textfile3.txt textfile4.txt
# Human ans:  paste <(nl /testbed/dir3/subdir1/subsubdir1/textfile3.txt) <(nl /testbed/dir1/subdir1/textfile4.txt)
# ------------------

# %%
n_exact_matches
# Out:
# 44
